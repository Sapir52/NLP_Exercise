# %%
#!pip install advertools
#!pip install hebrew_tokenizer
! pip install -q pyspark==3.2.0 spark-nlp
#!cd ~/cache_pretrained && ls -l
# Out:
#      |████████████████████████████████| 281.3 MB 35 kB/s
#      |████████████████████████████████| 145 kB 13.6 MB/s
#      |████████████████████████████████| 198 kB 28.4 MB/s
#   Building wheel for pyspark (setup.py) ... done

# %%
import sparknlp
spark = sparknlp.start(spark32=True)
from sparknlp.base import *
from sparknlp.annotator import *
print("Spark NLP version", sparknlp.version())
print("Apache Spark version:", spark.version)

spark
# Out:
# Spark NLP version 3.4.4
# Apache Spark version: 3.2.0
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://aa34829e2d32:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark NLP</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import codecs
#import hebrew_tokenizer as ht
import re
import string
import pandas as pd
from pyspark.ml import Pipeline
import pyspark.sql.functions as F

# %%
data = list(codecs.open('hebrew_text.tsv', 'r', 'utf-8').readlines())
data_df =pd.DataFrame({'text':data})
from pyspark.sql import SQLContext
from pyspark import SparkContext
sc = SparkContext.getOrCreate()
sqlContext = SQLContext(sc)

spark_dff = sqlContext.createDataFrame(data_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/pyspark/sql/context.py:79: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   FutureWarning

# %%
documentAssembler = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")
#----------------------------------------------------------
tokenizer = Tokenizer() \
    .setInputCols(["document"]) \
    .setOutputCol("token")
#----------------------------------------------------------
stemmer = Stemmer() \
    .setInputCols(["token"]) \
    .setOutputCol("stem")
#----------------------------------------------------------
lemmatizer = LemmatizerModel.pretrained("lemma", "he") \
        .setInputCols(["token"]) \
        .setOutputCol("lemma")
#----------------------------------------------------------
# we can also get the list of stopwords 
stopwords_cleaner_he = StopWordsCleaner.pretrained('stopwords_he','he')\
        .setInputCols("stem")\
        .setOutputCol("stopwords")\
        .setCaseSensitive(False)

token_assembler = TokenAssembler() \
    .setInputCols(["document", "stopwords"]) \
    .setOutputCol("cleanStopwords")
#----------------------------------------------------------
pos = PerceptronModel.pretrained("pos_ud_htb", "he") \
    .setInputCols(["document", "token"]) \
    .setOutputCol("pos")
#----------------------------------------------------------
# applying POS chunker to find a custom pattern
chunker = Chunker()\
    .setInputCols(["document", "pos"])\
    .setOutputCol("chunk")\
    .setRegexParsers(["<NOUN>", "<ADJ>","<ADV>","<AUX>","<INTJ>","<PROPN>", "<VERB>","<None>"]) 
#chunker.extractParamMap()
#----------------------------------------------------------
spell_checker_norvig = NorvigSweetingModel.pretrained('spellcheck_norvig')\
        .setInputCols("token")\
        .setOutputCol("corrected")
#----------------------------------------------------------
# Out:
# lemma download started this may take some time.
# Approximate size to download 169 KB
# [OK!]
# stopwords_he download started this may take some time.
# Approximate size to download 2 KB
# [OK!]
# pos_ud_htb download started this may take some time.
# Approximate size to download 2.6 MB
# [OK!]
# spellcheck_norvig download started this may take some time.
# Approximate size to download 4.2 MB
# [OK!]

# %%
nlpPipeline = Pipeline(stages=[
    documentAssembler, 
    tokenizer,
    stemmer,
    lemmatizer,
    stopwords_cleaner_he,
    pos,
    chunker,
    token_assembler
 ])



empty_df = spark.createDataFrame([['']]).toDF("text")
pipelineModel = nlpPipeline.fit(empty_df)

# %%
result = pipelineModel.transform(spark_dff)
result.show(10)
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |                text|            document|               token|                stem|               lemma|           stopwords|                 pos|               chunk|      cleanStopwords|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |ממש כואב ..... אנ...|[{document, 0, 52...|[{token, 0, 2, ממ...|[{token, 0, 2, ממ...|[{token, 0, 2, ממ...|[{token, 0, 2, ממ...|[{pos, 0, 2, ADV,...|[{chunk, 27, 32, ...|[{document, 0, 44...|
# |   איש יקר שלנו\t0\n|[{document, 0, 14...|[{token, 0, 2, אי...|[{token, 0, 2, אי...|[{token, 0, 2, אי...|[{token, 0, 2, אי...|[{pos, 0, 2, NOUN...|[{chunk, 0, 2, אי...|[{document, 0, 8,...|
# |כל הכבוד והמון בה...|[{document, 0, 23...|[{token, 0, 1, כל...|[{token, 0, 1, כל...|[{token, 0, 1, כו...|[{token, 3, 7, הכ...|[{pos, 0, 1, DET,...|[{chunk, 3, 7, הכ...|[{document, 0, 19...|
# |" תל חי , רובי . ...|[{document, 0, 75...|[{token, 0, 0, ",...|[{token, 0, 0, ",...|[{token, 0, 0, ",...|[{token, 0, 0, ",...|[{pos, 0, 0, PUNC...|[{chunk, 2, 3, תל...|[{document, 0, 68...|
# |נקי כפיים ובר לבב...|[{document, 0, 36...|[{token, 0, 2, נק...|[{token, 0, 2, נק...|[{token, 0, 2, נק...|[{token, 0, 2, נק...|[{pos, 0, 2, NOUN...|[{chunk, 0, 2, נק...|[{document, 0, 35...|
# |רובי חג שמח והצלח...|[{document, 0, 38...|[{token, 0, 3, רו...|[{token, 0, 3, רו...|[{token, 0, 3, רו...|[{token, 0, 3, רו...|[{pos, 0, 3, PROP...|[{chunk, 5, 6, חג...|[{document, 0, 37...|
# |הנשיא לא נותן יד ...|[{document, 0, 11...|[{token, 0, 4, הנ...|[{token, 0, 4, הנ...|[{token, 0, 4, הנ...|[{token, 0, 4, הנ...|[{pos, 0, 4, None...|[{chunk, 14, 15, ...|[{document, 0, 10...|
# |כבוד הנשיא אין מת...|[{document, 0, 17...|[{token, 0, 3, כב...|[{token, 0, 3, כב...|[{token, 0, 3, כב...|[{token, 0, 3, כב...|[{pos, 0, 3, NOUN...|[{chunk, 0, 3, כב...|[{document, 0, 14...|
# |" כל הכבוד לך אדו...|[{document, 0, 69...|[{token, 0, 0, ",...|[{token, 0, 0, ",...|[{token, 0, 0, ",...|[{token, 0, 0, ",...|[{pos, 0, 0, PUNC...|[{chunk, 5, 9, הכ...|[{document, 0, 61...|
# |אדוני הנשיא סליחה...|[{document, 0, 21...|[{token, 0, 4, אד...|[{token, 0, 4, אד...|[{token, 0, 4, אד...|[{token, 0, 4, אד...|[{pos, 0, 4, PROP...|[{chunk, 12, 16, ...|[{document, 0, 18...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 10 rows

# %%
result.select('stem.result', 'cleanStopwords.result', 'chunk.result').show(30, truncate=100)
# Out:
# +----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# |                                                                                              result|                                                                                              result|                                                                                              result|
# +----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# |                                   [ממש, כואב, ....., אני, בוכה, עם, המשפחה, שלא, תדעו, עוד, צער, 0]|                                                     [ממש כואב ..... בוכה המשפחה שלא תדעו עוד צער 0]|                                                      [המשפחה, צער, ממש, שלא, עוד, כואב, בוכה, תדעו]|
# |                                                                                 [איש, יקר, שלנו, 0]|                                                                                         [איש יקר 0]|                                                                                    [איש, יקר, שלנו]|
# |                                                                       [כל, הכבוד, והמון, בהצלחה, 0]|                                                                              [הכבוד והמון בהצלחה 0]|                                                                              [הכבוד, והמון, בהצלחה]|
# |   [", תל, חי, ,, רובי, ., בכל, העצב, הזה, היית, קרן, אור, של, תקוה, ., אכן, יש, נשיא, בישראל, ", 0]|                             [" תל חי , רובי . בכל העצב הזה היית קרן אור תקוה . אכן נשיא בישראל " 0]|                         [תל, העצב, היית, קרן, אור, נשיא, חי, אכן, רובי, תקוה, יש, בכל, הזה, בישראל]|
# |                                                      [נקי, כפיים, ובר, לבב, בהצלחה, לך, ולנו, ., 0]|                                                              [נקי כפיים ובר לבב בהצלחה לך ולנו . 0]|                                                            [נקי, כפיים, בהצלחה, ולנו, לבב, לך, ובר]|
# |                                                     [רובי, חג, שמח, והצלחה, בבחירות, לנשיאות, ., 0]|                                                            [רובי חג שמח והצלחה בבחירות לנשיאות . 0]|                                                           [חג, והצלחה, בבחירות, רובי, שמח, לנשיאות]|
# |[הנשיא, לא, נותן, יד, ., דיי, להתלהמות, אפשר, להביע, דיעה, ולהתנגד, אך, לא, פיזית, ., זו, הבחירה,...|[הנשיא נותן יד . דיי להתלהמות אפשר להביע דיעה ולהתנגד פיזית . זו הבחירה להנשא למוסלמי . נאחל הצלח...|[יד, דיי, דיעה, הבחירה, הצלחה, ולהתנגד, פיזית, לא, לא, אפשר, לה, נותן, להתלהמות, להביע, להנשא, למ...|
# |[כבוד, הנשיא, אין, מתאים, ממך, בעולם, מלהיות, נשיא, מדינת, ישראל, עם, ישראל, אוהב, אותך, והקב, ׳,...|[כבוד הנשיא מתאים ממך בעולם מלהיות נשיא מדינת ישראל ישראל אוהב והקב ׳ ה אוהב ואתה דוגמה ומופת לכל...|[כבוד, ממך, נשיא, מדינת, אותך, והקב, אוהב, דוגמה, אדם, אושר, עושר, ובריאות, מלהיות, איתנה, אין, ב...|
# |             [", כל, הכבוד, לך, אדוני, הנשיא, כאיש, ימין, דווקא, ,, אני, חושב, שאהבה, תנצח, ., ", 0]|                                    [" הכבוד לך אדוני הנשיא כאיש ימין דווקא , חושב שאהבה תנצח . " 0]|                                           [הכבוד, ימין, שאהבה, אדוני, דווקא, תנצח, לך, חושב, הנשיא]|
# |[אדוני, הנשיא, סליחה, על, הבוטות, תפסיק, לזיין, את, השכל, ., עד, היום, לא, התבטאת, ולו, במילה, על...|[אדוני הנשיא סליחה הבוטות תפסיק לזיין השכל . היום התבטאת ולו במילה המצב במדינה . הבעת אהדתך לצבא ...|[סליחה, הבוטות, תפסיק, השכל, ולו, במדינה, אהדתך, מילה, הדרום, טובה, היום, לא, במילה, לא, לא, אז, ...|
# |                                                                           [בהצלחה, אדוני, הנשיא, 0]|                                                                              [בהצלחה אדוני הנשיא 0]|                                                                              [אדוני, בהצלחה, הנשיא]|
# |                                                          [ואני, עוד, חשבתי, שהגיע, נשיא, נורמלי, 1]|                                                                [ואני עוד חשבתי שהגיע נשיא נורמלי 1]|                                                             [נשיא, עוד, ואני, נורמלי, חשבתי, שהגיע]|
# |[נשיא, המדינה, הלבן, והמנותק, חכם, בדיבורים, ., הוא, לא, יהיה, שם, ברגע, האמת, לעזור, לה, לטפל, ב...|[נשיא המדינה הלבן והמנותק חכם בדיבורים . ברגע האמת לעזור לטפל בפצעי המכות האיומות שהיא תקבל . מנו...|[נשיא, הלבן, בדיבורים, בפצעי, המכות, האיומות, חכם, לא, שם, ברגע, לו, יהיה, והמנותק, לה, ומנוכר, מ...|
# |[", דרך, צלחה, בים, סוער, !!!, מאמינה, שתמשיך, לנהוג, כפי, שנהגת, בהיותך, יו, ״, ר, הכנסת, ,, ביו...|[" צלחה בים סוער !!! מאמינה שתמשיך לנהוג שנהגת בהיותך יו ״ ר הכנסת , ביושרה ובליברליות נאורה , וב...|[דרך, צלחה, בים, שתמשיך, שנהגת, בהיותך, יו, ״, הכנסת, ובליברליות, הביצה, סוער, נאורה, הפוליטית, ר...|
# |[", רובי, ריבלין, היקר, !!, אתה, איש, משפחה, לא, ???.., מעניין, איך, היית, מגיב, -, אם, הבת, שלך,...|[" רובי ריבלין היקר !! איש משפחה ???.. מעניין היית מגיב - הבת הייתה מתחתנת היום ערבי .... נשיא מד...|[!!, איש, משפחה, מעניין, ערבי, נשיא, מדינה, בעם, מעודד, לא, איך, הייתה, היום, היית, רובי, ריבלין,...|
# |                                                                                 [מגיע, לך, !!!!, 0]|                                                                                    [מגיע לך !!!! 0]|                                                                                    [מגיע, לך, !!!!]|
# |                                                                                            [אמן, 0]|                                                                                             [אמן 0]|                                                                                               [אמן]|
# |                                  [", ווא, מרגש, !, בעזרת, ה, ׳, ,, ,, נשיא, מדינת, ישראל, !!, ", 0]|                                                [" ווא מרגש ! בעזרת ה ׳ , , נשיא מדינת ישראל !! " 0]|                                                           [ווא, ׳, נשיא, מדינת, ישראל, מרגש, בעזרת]|
# |                                               [עוד, לא, שבוע, בתפקיד, וכבר, שכחת, מאיפה, באת, ?, 1]|                                                                 [עוד שבוע בתפקיד וכבר שכחת באת ? 1]|                                                     [שבוע, בתפקיד, שכחת, מאיפה, עוד, לא, וכבר, באת]|
# |                                                                                         [בהצלחה, 0]|                                                                                          [בהצלחה 0]|                                                                                            [בהצלחה]|
# |[אדוני, הנשיא, ., אם, הדמוקרטיה, ועתיד, הדו, קיום, חשובים, לך, עשה, מעשה, ולך, להיות, אורח, של, כ...|           [אדוני הנשיא . הדמוקרטיה ועתיד הדו קיום חשובים לך עשה מעשה ולך אורח כבוד בחתונה הזאת . 0]|[הדו, קיום, מעשה, אורח, כבוד, חשובים, להיות, אדוני, ועתיד, ולך, בחתונה, הזאת, הדמוקרטיה, לך, עשה,...|
# |[", ריבלין, הרגע, מחקתי, אותך, ,, כמה, אהבתי, אותך, על, זה, נאמר, ", ", סייג, לחוכמה, שתיקה, ", "...|                                [" ריבלין הרגע מחקתי , כמה אהבתי נאמר " " סייג לחוכמה שתיקה " " " 1]|                                 [מחקתי, אותך, אהבתי, שתיקה, ריבלין, הרגע, אותך, נאמר, סייג, לחוכמה]|
# |                                                     [אם, יש, מישהו, שמגיעה, לו, זה, אתה..בהצלחה, 0]|                                                                        [מישהו שמגיעה אתה..בהצלחה 0]|                                                                [מישהו, לו, יש, שמגיעה, אתה..בהצלחה]|
# |                                                [תתחיל, במעשים, !!, עוד, אחד, פחדן, !, כהנא, צדק, 1]|                                                         [תתחיל במעשים !! עוד אחד פחדן ! כהנא צדק 1]|                                                           [תתחיל, במעשים, פחדן, עוד, כהנא, !!, צדק]|
# |[", כבוד, נשיאנו, ,, אין, שמח, היה, ממני, ביום, בחירתך, ,, לא, חשבתי, שכל, כך, מהר, אשמע, את, שמע...|                  [" כבוד נשיאנו , שמח ממני ביום בחירתך , חשבתי שכל מהר אשמע שמעון פרס מגרונך , " 1]|         [כבוד, ממני, שכל, אין, לא, מהר, היה, נשיאנו, בחירתך, שמעון, פרס, חשבתי, אשמע, מגרונך, ביום]|
# |        [", עם, התגובות, שנכתבות, פה, ,, יש, לך, הרבה, עבודה, לעשות, בתור, נשיא, ,, בהצלחה, !, ", 0]|                                  [" התגובות שנכתבות , לך הרבה עבודה לעשות בתור נשיא , בהצלחה ! " 0]|                                    [התגובות, שנכתבות, עבודה, בתור, נשיא, פה, יש, לך, לעשות, בהצלחה]|
# |                        [רובי, ..., בדיחה, אחת, בשבוע, ..., עם, ישראל, זקוק, לחיוך, מידי, פעם, ., 0]|                                        [רובי ... בדיחה אחת בשבוע ... ישראל זקוק לחיוך מידי פעם . 0]|                                                       [בדיחה, פעם, זקוק, רובי, ישראל, לחיוך, בשבוע]|
# |[", כבוד, הנשיא, הבא, עלינו, לטובה, ., שמח, לפגישתך, העתידית, עם, אבו, מאזן, ,, בקש, שיסביר, איך,...|[" כבוד הנשיא הבא לטובה . שמח לפגישתך העתידית אבו מאזן , בקש שיסביר מתישב הסדר שהוא : הרשות הפלסט...|[כבוד, שמח, מאזן, הסדר, הרשות, הפלסטינית, חודש, משכורות, הכלואים, חודש, משלמים, כסף, שנים, ש""ח, ...|
# |[לפי, הזמן, שפרסמת, את, הפוסט, ., הכלה, הטריה, והמסכנה, קמה, בבוקר, וקיבלה, וואחד, עידוד, נשיאותי...|[לפי הזמן שפרסמת הפוסט . הכלה הטריה והמסכנה קמה בבוקר וקיבלה וואחד עידוד נשיאותי . עוד הרהור תשוב...|[הזמן, הכלה, בבוקר, וקיבלה, עידוד, הרהור, תשובה, מסכנה, עמוד, שדרה, הכף, כבוד, פנים, ההודעות, יומ...|
# |                               [", כבוד, הנשיא, ,, כל, הכבוד, ,, אני, תומך, בכל, מילה, שלך, ., ", 0]|                                                        [" כבוד הנשיא , הכבוד , תומך בכל מילה . " 0]|                                                          [כבוד, הכבוד, מילה, שלך, תומך, הנשיא, בכל]|
# +----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+----------------------------------------------------------------------------------------------------+
# only showing top 30 rows

# %%
from pyspark.sql import functions as F
result_df = result.select(F.explode(F.arrays_zip(result.token.result, 
                                                 result.stem.result, 
                                                 result.lemma.result, 
                                                 result.pos.result)).alias("cols")) \
                  .select(F.expr("cols['0']").alias("token"),
                          F.expr("cols['1']").alias("stem"),
                          F.expr("cols['2']").alias("lemma"),
                          F.expr("cols['3']").alias("pos")).toPandas()

# %%
result_df.head(30)
# Out:
#      token    stem   lemma    pos
# 0      ממש     ממש     ממש    ADV
# 1     כואב    כואב     כאב   VERB
# 2    .....   .....   .....  PUNCT
# 3      אני     אני     הוא   PRON
# 4     בוכה    בוכה    בוכה   VERB
# 5       עם      עם      עם    ADP
# 6   המשפחה  המשפחה  המשפחה   NOUN
# 7      שלא     שלא     שלא    ADV
# 8     תדעו    תדעו    תדעו   VERB
# 9      עוד     עוד     עוד    ADV
# 10     צער     צער     צער   NOUN
# 11       0       0       0    NUM
# 12     איש     איש     איש   NOUN
# 13     יקר     יקר     יקר    ADJ
# 14    שלנו    שלנו    שלנו   VERB
# 15       0       0       0    NUM
# 16      כל      כל     כול    DET
# 17   הכבוד   הכבוד   הכבוד   NOUN
# 18   והמון   והמון   והמון   NOUN
# 19  בהצלחה  בהצלחה  בהצלחה   NOUN
# 20       0       0       0    NUM
# 21       "       "       "  PUNCT
# 22      תל      תל      תל   NOUN
# 23      חי      חי      חי    ADJ
# 24       ,       ,       ,  PUNCT
# 25    רובי    רובי    רובי  PROPN
# 26       .       .       .  PUNCT
# 27     בכל     בכל     בכל   None
# 28    העצב    העצב    העצב   NOUN
# 29     הזה     הזה     הזה   None
